# %% [markdown]
# # 02 — ACFA Model Evaluation (Milestone 5 & Milestone 6)
#
# This notebook evaluates model performance on the untouched test set (`test.csv`):
# 1. **Baseline CNN Evaluation** (`acfa_cnn_best.pth`).
# 2. **ResNet18 Transfer Learning Evaluation** (`resnet18_best.pth`).
# 3. **Model Performance Comparison** (Accuracy, Precision, Recall, F1-Score, Confusion Matrices).

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import json

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.evaluation import run_baseline_cnn_evaluation

print("Project Root:", project_root)

# %% [markdown]
# ## 1. Baseline CNN Evaluation Results

# %%
cnn_json_path = os.path.join(project_root, "results", "metrics", "cnn_metrics.json")
if os.path.exists(cnn_json_path):
    with open(cnn_json_path, "r") as f:
        cnn_metrics = json.load(f)
    print("Overall Baseline CNN Metrics:")
    print(json.dumps(cnn_metrics["overall_metrics"], indent=2))

cnn_csv_path = os.path.join(project_root, "results", "metrics", "cnn_classification_report.csv")
if os.path.exists(cnn_csv_path):
    print("
Per-Class Classification Report:")
    display(pd.read_csv(cnn_csv_path))
